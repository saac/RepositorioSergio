# %%
import math as mt

# %%
def TiempoEcoli(rp,rb,tr):
    tf = 5
    print("Aqui pasara algo")
    return tf

# %%
TiempoEcoli(2,1,4)
# Out:
# Aqui pasara algo
# 5

# %%
rp = 6371 # Km
rb = 0.5 # micrometros
tr = 2 # cada media hr

# Rpm = CAM(rp)
# Rbm = CAM(rb)
Rpm = rp*1e3 # 1e3 = 1000
Rbm = rb*1e-6

N = (Rpm/Rbm)**3
print(N)

t = mt.log2(N)
tf = t/48
print(tf,"dias, corran!")
# Out:
# 2.068772822488e+39
# 2.720916061005779 dias, corran!

# %%
def TiempoEcoli(rp,rb,tr):

    print("rp es igual a:",rp)
    print("rb es igual a:",rb)
    print("tr es igual a:",tr)
    
    # tr = 2 # cada media hr
    print("tr es igual a:",tr)
    
    # Rpm = CAM(rp)
    # Rbm = CAM(rb)
    Rpm = rp*1e3 # 1e3 = 1000
    Rbm = rb*1e-6
    
    N = (Rpm/Rbm)**3
    print("N =",N)
    
    t = mt.log2(N)
    tf = t/48
    print(tf,"dias, corran!")
    # return tf

# %%
TiempoEcoli(6666371,0.15,333)
# Out:
# rp es igual a: 6666371
# rb es igual a: 0.15
# tr es igual a: 333
# tr es igual a: 333
# N = 8.777981505849595e+49
# 3.4564242891686816 dias, corran!

# %%
def TiempoEcoli(rp,rb,tr):

    Rpm = rp*1e3 # 1e3 = 1000
    Rbm = rb*1e-6
    
    N = (Rpm/Rbm)**3
    print("N =",N)
    
    t = mt.log2(N)
    tf = t/48
    print(tf,"dias, corran!")
    # return tf

# %%
TiempoEcoli(6666371,0.15,333)
# Out:
# N = 8.777981505849595e+49
# 3.4564242891686816 dias, corran!

# %%
def TiempoEcoliB(rp,rb,dn,dt):

    Rpm = rp*1e3 # 1e3 = 1000
    Rbm = rb*1e-6
    
    N = (Rpm/Rbm)**3
    # print("N =",N)
    
    # t = mt.log2(N)
    t = mt.log(N,dn)
    
    tf = t/48
    
    return N,tf

# %%
# ENE, tiempo = TiempoEcoliB(6371,0.5,2,1)
TiempoEcoliB(6371,0.5,4,1)
# Out:
# (2.068772822488e+39, 1.3604580305028895)

# %%
tiempo
# Out:
# 2.720916061005779

# %%
ENE
# Out:
# 2.068772822488e+39

# %%
t = mt.log?
# Out:
# Docstring:
# log(x, [base=math.e])
# Return the logarithm of x to the given base.
#
# If the base is not specified, returns the natural logarithm (base e) of x.
# Type:      builtin_function_or_method

# %%
# rp debe estar en Km
# rb debe estar en micras
# ut debe estar en horas

def TiempoEcoliC(rp,rb,dn,ut):

    Rpm = rp*1e3 # 1e3 = 1000
    Rbm = rb*1e-6
    
    N = (Rpm/Rbm)**3
    t = mt.log(N,dn)

    tf = t*ut

    tf = tf/24

    print("Se tarda",tf,"dias")
    
    return N,tf

# %%
Rj = 71492
Rvl = 15*1e24
Rt = 6371

TiempoEcoliC(Rt,0.5,2,1/3)
# Out:
# Se tarda 1.8139440406705194 dias
# (2.068772822488e+39, 1.8139440406705194)

# %%
60/12
# Out:
# 5.0
